# %%
# import required libraries 
import pandas as pd
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# read the corona dataset 
data = pd.read_csv('/content/drive/MyDrive/Corona_NLP_test.csv')

# create a list of tokens for each tweet
tokenized_tweets = [nltk.word_tokenize(tweet.lower()) for tweet in data['OriginalTweet']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# download stopwords if not already downloaded
nltk.download('stopwords')

# create a list of stopwords
stop_words = stopwords.words('english')

# remove stop words from tokenized tweets
tweets_without_stopwords = [[word for word in tweet if not word in stop_words] for tweet in tokenized_tweets]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# create a list of all words in all tokenized tweets
all_words = [word for tweet in tokenized_tweets for word in tweet]

# count the frequency of each word
word_freq = Counter(all_words)

# %%
# create a WordCloud object
wordcloud = WordCloud(width=600, height=600, background_color='black', max_words=100).generate_from_frequencies(word_freq)

# plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
